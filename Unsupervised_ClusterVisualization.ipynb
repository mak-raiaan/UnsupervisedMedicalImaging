# %%
# of ISIC2019 dataset

import matplotlib.pyplot as plt

cluster_colors = ['Yellow', 'Cyan', 'Magenta', 'Brown', 'Gray', 'Teal']
cluster_labels = ['MEL', 'BCC', 'AK', 'SCC', 'NV', 'BKL']

plt.figure(figsize=(8, 8))
for i in range(num_clusters):
    cluster_points = isic_histograms[labels == i]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], c=cluster_colors[i], s=30, label=f'{cluster_labels[i]}')

plt.title('t-SNE [ISIC 2019]')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(loc='upper right')
plt.show()

# %%
# of HAM10000 dataset

import matplotlib.pyplot as plt

cluster_colors = ['Yellow', 'Cyan', 'Magenta', 'Gray', 'Teal']
cluster_labels = ['MEL', 'BCC', 'AK', 'NV', 'BKL']

plt.figure(figsize=(8, 8))
for i in range(num_clusters):
    cluster_points = ham10000_histograms[labels == i]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], c=cluster_colors[i], s=30, label=f'{cluster_labels[i]}')

plt.title('t-SNE [HAM10000]')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(loc='upper right')
plt.show()
